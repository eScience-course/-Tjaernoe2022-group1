# %%
import os
import pathlib
import s3fs
import xarray as xr

# %%
target = s3fs.S3FileSystem(#anon=False,
      client_kwargs={
         'endpoint_url': 'https://object-store.cloud.muni.cz'
      })

# %%
s3_prefix =  "s3://escience/"+'sarambl/DATA_ZEP_2010to2020'
print(s3_prefix)
# Out:
# s3://escience/sarambl/DATA_ZEP_2010to2020

# %%
from pathlib import Path

# %%
s3 = s3fs.S3FileSystem(key="K1CQ7M1DMTLUFK182APD", 
                       secret="3JuZAQm5I03jtpijCpHOdkAsJDNLNfZxBpM15Pi0", 
                       client_kwargs=dict(endpoint_url="https://rgw.met.no"))
s3.ls('escience2022/sarambl/')
# Out:
# []

# %%
target.ls('s3://escience/sarambl/DATA_ZEP_2010to2020/')
# Out:
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/aiohttp/connector.py:986, in TCPConnector._wrap_create_connection(self, req, timeout, client_error, *args, **kwargs)
#     985     async with ceil_timeout(timeout.sock_connect):
# --> 986         return await self._loop.create_connection(*args, **kwargs)  # type: ignore[return-value]  # noqa
#     987 except cert_errors as exc:
#
# File /srv/conda/envs/notebook/lib/python3.9/asyncio/base_events.py:1050, in BaseEventLoop.create_connection(self, protocol_factory, host, port, ssl, family, proto, flags, sock, local_addr, server_hostname, ssl_handshake_timeout, happy_eyeballs_delay, interleave)
#    1049 try:
# -> 1050     sock = await self._connect_sock(
#    1051         exceptions, addrinfo, laddr_infos)
#    1052     break
#
# ...

# %%
dsmf11_aero = xr.open_dataset('User/stefanpfaller/Downloads/dNdlogD_data_dmps_cleaned_2010-2020.nc')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/backends/file_manager.py:201, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     200 try:
# --> 201     file = self._cache[self._key]
#     202 except KeyError:
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/xarray/backends/lru_cache.py:55, in LRUCache.__getitem__(self, key)
#      54 with self._lock:
# ---> 55     value = self._cache[key]
#      56     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/home/jovyan/Tjaernoe2022-group1/notebooks/Stefan/User/stefanpfaller/Downloads/dNdlogD_data_dmps_cleaned_2010-2020.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False))]
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
import glob

# %%
glob.glob('stefanpfaller/*')
# Out:
# []
